# %%
import pandas as pd 
import numpy as np
import random
from pandas import DataFrame,Series

people=DataFrame(np.random.randn(5,5), columns=['a','b','c','d','e'],
                 index=['Joe','Steve','Wes','Jim','Travis'])
people
# Out:
#                a         b         c         d         e
# Joe     0.070463  1.082644 -0.902312 -1.317378  0.973519
# Steve   0.753108  0.580094 -1.795290  1.565341 -2.264093
# Wes     1.718401  0.212135  0.611825 -0.608191 -0.993634
# Jim     0.801437  0.074862  1.016829 -0.117975  1.106974
# Travis  0.034842 -0.257445 -2.217351  0.115925  1.084145

# %%
# df.mean(axis=1)
people.sum()
# Out:
# a    0.110166
# b    0.454531
# c   -4.277618
# d    1.345453
# e   -0.714328
# dtype: float64

# %%
people.drop('a',axis=1,inplace=True)

# %%
people
# Out:
#                b         c         d         e
# Joe     0.228527  0.051663 -0.083384  0.018209
# Steve   0.936329  0.632371  0.145855  1.380079
# Wes    -1.420777 -2.176909 -0.472982  0.029289
# Jim     1.065128 -1.661431  1.614540 -2.027548
# Travis -0.354676 -1.123312  0.141424 -0.114356

# %%
people
# Out:
#                b         c         d         e
# Joe     0.228527  0.051663 -0.083384  0.018209
# Steve   0.936329  0.632371  0.145855  1.380079
# Wes    -1.420777 -2.176909 -0.472982  0.029289
# Jim     1.065128 -1.661431  1.614540 -2.027548
# Travis -0.354676 -1.123312  0.141424 -0.114356

# %%
s = pd.Series([1,3,5,np.nan,6,8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
s.dropna()
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 4    6.0
# 5    8.0
# dtype: float64

# %%
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
import time
import pandas as pd
import random
import numpy as np
df= pd.DataFrame(np.random.randn(6,4),columns=list('ABCD'))
df
# Out:
#           A         B         C         D
# 0  0.313004 -0.912683  0.352400 -0.221199
# 1 -0.033199  1.949063  0.983179 -1.524123
# 2 -0.931260 -2.176657 -0.904807  0.474107
# 3 -1.583376 -0.815675  0.269071 -0.213618
# 4  0.234753  0.992865  0.284854  0.005290
# 5  0.656248 -0.925322 -1.123622  0.039383

# %%
# df.sort_values(by='B')
df.sort_index(axis=0,ascending=False)
# Out:
#           A         B         C         D
# 5  0.656248 -0.925322 -1.123622  0.039383
# 4  0.234753  0.992865  0.284854  0.005290
# 3 -1.583376 -0.815675  0.269071 -0.213618
# 2 -0.931260 -2.176657 -0.904807  0.474107
# 1 -0.033199  1.949063  0.983179 -1.524123
# 0  0.313004 -0.912683  0.352400 -0.221199

# %%
df[df.A>0]
# Out:
#           A         B         C         D
# 0  0.313004 -0.912683  0.352400 -0.221199
# 4  0.234753  0.992865  0.284854  0.005290
# 5  0.656248 -0.925322 -1.123622  0.039383

# %%
df2=df.copy()
df2['E']=['one','two','three','four','five','six']

df2
# Out:
#           A         B         C         D      E
# 0  0.313004 -0.912683  0.352400 -0.221199    one
# 1 -0.033199  1.949063  0.983179 -1.524123    two
# 2 -0.931260 -2.176657 -0.904807  0.474107  three
# 3 -1.583376 -0.815675  0.269071 -0.213618   four
# 4  0.234753  0.992865  0.284854  0.005290   five
# 5  0.656248 -0.925322 -1.123622  0.039383    six

# %%
df2.rename(columns={'A':'a','B':'b','E':'e'},inplace=True)

# %%
df2
# Out:
#           a         b         C         D      e
# 0  0.313004 -0.912683  0.352400 -0.221199    one
# 1 -0.033199  1.949063  0.983179 -1.524123    two
# 2 -0.931260 -2.176657 -0.904807  0.474107  three
# 3 -1.583376 -0.815675  0.269071 -0.213618   four
# 4  0.234753  0.992865  0.284854  0.005290   five
# 5  0.656248 -0.925322 -1.123622  0.039383    six

# %%
import numpy as np
import pandas as pd 
import random

df = pd.DataFrame({'key1':[1,2,3,4,5],'key2':[11,22,33,44,55]},index=['A','B','C','D','E'])
df

# %%
key2=df.pop('key2')

# %%
df

# %%
df2=df.copy()

# %%
df2

# %%
df2['key1']='key3'

# %%
df2

# %%
df2[df2['key1']]='key3'

# %%
df2

# %%
df2.insert(0,'key2',key2)

# %%
df2

# %%
df2['key2']

# %%
df2.key2

# %%
dd=pd.read_html('https://baike.baidu.com/item/NBA%E6%80%BB%E5%86%A0%E5%86%9B/2173192?fr=aladdin')

# %%
dd

# %%
com = dd[0]

# %%
com

# %%
com.head()

# %%
com.columns=com.iloc[0]

# %%
com

# %%
com.drop([0],inplace=True)

# %%
com

# %%
com.groupby('冠军').groups

# %%
tt=com.groupby('冠军').size().sort_values(ascending=False)

# %%
tt

# %%
tt.to_excel('./NBA1.xlsx',index=False)

# %%
df = pd.read_clipboard()
dff = df.groupby('A').apply(lambda x:x.sort_values('B')).reset_index(drop=True)
groups = dff['A'].unique()
dff_gp = dff.groupby('A')
# for group in groups:
#     print('\n')
#     print(dff_gp.get_group(group))
a = df.groupby('A')
b = df.groupby('A')['B']
type(a)
# type(b)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
import pandas as pd 
import numpy as np

canadian_youtube=pd.read_csv('D:/Wowode/jupyterlab/CAvideos/CAvideos.csv')
canadian_youtube.head(20)
# Out:
#        video_id trending_date  \
# 0   n1WpP7iowLc      17.14.11
# 1   0dBIkQ4Mz1M      17.14.11
# 2   5qpjK5DgCt4      17.14.11
# 3   d380meD0W0M      17.14.11
# 4   2Vv-BfVoq4g      17.14.11
# 5   0yIWz1XEeyc      17.14.11
# 6   _uM5kFfkhB8      17.14.11
# 7   2kyS6SvSYSE      17.14.11
# 8   JzCsM1vtn78      17.14.11
# 9   43sm-QwLcx4      17.14.11
# 10  H1KBHFXm2Bg      17.14.11
# 11  U3xLOo-CNwo      17.14.11
# 12  FyZMnhUtLfE      17.14.11
# 13  7MxiQ4v0EnE      17.14.11
# 14  LUzsOyWp9lw      17.14.11
# 15  AS9-ITLhQxo      17.14.11
# 16  gifPYwArCVQ      17.14.11
# 17  8NHA23f7LvU      17.14.11
# 18  fy-CuCzaPp8      17.14.11
# 19  kzwfHumJyYc      17.14.11
#
#                                                 title           channel_title  \
# 0          Eminem - Walk On Water (Audio) ft. Beyoncé              EminemVEVO
# 1                       PLUSH - Bad Unboxing Fan Mail               iDubbbzTV
# 2   Racist Superman | Rudy Mancuso, King Bach & Le...            Rudy Mancuso
# ...

# %%
canadian_youtube = pd.read_csv(r"D:\Wowode\jupyterlab\CAvideos.csv.zip")
british_youtube = pd.read_csv(r"D:\Wowode\jupyterlab\GBvideos.csv.zip")
 
dd=pd.concat([canadian_youtube, british_youtube]).head()
dd.to_excel('cabr.xlsx',index=False)

# %%
d=pd.read_excel('cabr.xlsx',usecols=[0,1,2])

# %%
d
# Out:
#       video_id trending_date  \
# 0  n1WpP7iowLc      17.14.11
# 1  0dBIkQ4Mz1M      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  d380meD0W0M      17.14.11
# 4  2Vv-BfVoq4g      17.14.11
#
#                                                title
# 0         Eminem - Walk On Water (Audio) ft. Beyoncé
# 1                      PLUSH - Bad Unboxing Fan Mail
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                           I Dare You: GOING BALD!?
# 4        Ed Sheeran - Perfect (Official Music Video)

# %%
import timeit

import numpy
import pandas

def func_numpy():
    filepath = r'D:/Wowode/jupyterlab/CAvideos/CAvideos.csv'
    numpy.loadtxt(filepath, usecols=[0], delimiter=',')

def func_pandas():
    filepath = r'D:/Wowode/jupyterlab/CAvideos/CAvideos.csv'
    pandas.read_csv(filepath, usecols=[0])

def fun_pandas2numpy():
    filepath = r'D:/Wowode/jupyterlab/CAvideos/CAvideos.csv'
    pandas.read_csv(filepath, usecols=[0]).as_matrix()

# 开始计时
t_numpy = timeit.timeit('func_numpy()', 'from __main__ import func_numpy', number=2)
t_pandas = timeit.timeit('func_pandas()', 'from __main__ import func_pandas', number=2)
t_pandas2numpy = timeit.timeit('fun_pandas2numpy()', 'from __main__ import fun_pandas2numpy', number=2)
print('读取100次，numpy模块loadtxt方法用时：', t_numpy)
print('读取100次，pandas模块read_csv方法用时：', t_pandas)
print('读取100次，pandas模块read_csv方法读取后并将其转化为ndarray格式文件用时：', t_pandas2numpy)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-37-bdec4d08d5f7> in <module>
#      17
#      18 # 开始计时
# ---> 19 t_numpy = timeit.timeit('func_numpy()', 'from __main__ import func_numpy', number=2)
#      20 t_pandas = timeit.timeit('func_pandas()', 'from __main__ import func_pandas', number=2)
#      21 t_pandas2numpy = timeit.timeit('fun_pandas2numpy()', 'from __main__ import fun_pandas2numpy', number=2)
#
# c:\users\star\appdata\local\programs\python\python38\lib\timeit.py in timeit(stmt, setup, timer, number, globals)
#     231            number=default_number, globals=None):
#     232     """Convenience function to create Timer object and call timeit method."""
# --> 233     return Timer(stmt, setup, timer, globals).timeit(number)
#     234
#     235 def repeat(stmt="pass", setup="pass", timer=default_timer,
#
# ...
